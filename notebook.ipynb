# %% [markdown]
# ## Gastos registrados na Câmara dos Deputados utilizando cota parlamentar
#
# Este notebook objetiva prever de maneira exploratória os dados de gastos de deputados, disponibilizado pelo [Brasil.IO](https://brasil.io/dataset/gastos-deputados/cota_parlamentar).
#
# Autores: Anderson Pimentel; Davi Almeida Torobay; Filyppe Coelho; Nelson Reis.

# %%
import numpy as np
import pandas as pd
from sys import getsizeof

# %%
# fonte: https://brasil.io/dataset/gastos-deputados/cota_parlamentar
df = pd.read_csv('cota_parlamentar.csv.gz', compression='gzip')

# %%
# checa datas
line = 0
set_lines = set()
set_values = []

for value in df['datemissao']:
    type_value = type(value)
    if type_value != str:
        set_lines.add(line)
        set_values.append(value)
    line += 1
    
print(len(set_lines), 'linhas com problema de data')
# Out:
# 183862 linhas com problema de data

# %%
# checa valor máximo por series
dictc = {}

for c in df:
    
    if df[c].dtype in (np.float64, np.int64):
        maxvalue = df[c].max()
        maxuniq = len(df[c].unique())
        maxbytes = int(getsizeof(maxvalue))
        dictc[c] = {'max_value': maxvalue,
                    'max_bytes': maxbytes,
                    'unique_values': maxuniq}
    
    elif df[c].dtype == np.object:
        maxlen = 0
        maxvalue = 0
        
        for v in df[c]:
            try: newlen = len(v)
            except: continue
            
            if (newlen>maxlen):
                maxlen = newlen
                maxvalue = v
        
        maxbytes = int(getsizeof(maxvalue))
        
        dictc[c] = {'max_len': maxlen,
                    'max_value': maxvalue,
                    'max_bytes': maxbytes,
                    'unique_values':
                    maxuniq}

pdc = pd.DataFrame.from_dict(dictc)
pdc = pd.DataFrame.transpose(pdc)

# %%
pdc # "max_len" será NaN quando o tipo for numérico
# Out:
#                           max_bytes max_len  \
# codlegislatura                   32     NaN
# datemissao                       68      19
# idedocumento                     32     NaN
# idecadastro                      32     NaN
# indtipodocumento                 32     NaN
# nucarteiraparlamentar            32     NaN
# nudeputadoid                     32     NaN
# nulegislatura                    32     NaN
# numano                           32     NaN
# numespecificacaosubcota          32     NaN
# numlote                          32     NaN
# nummes                           32     NaN
# numparcela                       32     NaN
# numressarcimento                 32     NaN
# numsubcota                       32     NaN
# sgpartido                        67      18
# sguf                             51       2
# txnomeparlamentar                82      33
# txtcnpjcpf                       32     NaN
# txtdescricao                    133      60
# txtdescricaoespecificacao        93      20
# txtfornecedor                   191     142
# txtnumero                        79      30
# txtpassageiro                   173     100
# txttrecho                       173     100
# vlrdocumento                     32     NaN
# vlrglosa                         32     NaN
# vlrliquido                       32     NaN
# vlrrestituicao                   32     NaN
#
#                                                                    max_value  \
# codlegislatura                                                            56
# datemissao                                               2019-01-16 00:00:00
# idedocumento                                                      6.7616e+06
# idecadastro                                                           205303
# indtipodocumento                                                           4
# nucarteiraparlamentar                                                    674
# nudeputadoid                                                            3436
# nulegislatura                                                           2015
# numano                                                                  2019
# numespecificacaosubcota                                                    4
# numlote                                                          1.56713e+06
# nummes                                                                    12
# numparcela                                                                 1
# numressarcimento                                                           0
# numsubcota                                                               999
# sgpartido                                                 PROFESSOR LUIZINHO
# sguf                                                                      PE
# txnomeparlamentar                          PROFESSORA DORINHA SEABRA REZENDE
# txtcnpjcpf                                                       9.87499e+13
# txtdescricao               LOCAÇÃO DE VEÍCULOS AUTOMOTORES OU FRETAMENTO ...
# txtdescricaoespecificacao                               Veículos Automotores
# txtfornecedor              COOPERATIVA E PRESTACAO E SERVICO DE MOTORISTA...
# txtnumero                                     DE1A2294-89D7-4660-B70F-76D540
# txtpassageiro              AGNALDO HORÁCIO; ANDERSON VIDAL DOS SANTOS; CA...
# txttrecho                  manaus/carauari/manaus. Manaus/são Grabiel da ...
# vlrdocumento                                                          215000
# vlrglosa                                                               42250
# vlrliquido                                                            215000
# vlrrestituicao                                                         73200
#
#                           unique_values
# codlegislatura                        7
# datemissao                            7
# idedocumento                2.51317e+06
# idecadastro                        1225
# indtipodocumento                      5
# nucarteiraparlamentar               661
# nudeputadoid                       1243
# nulegislatura                         4
# numano                               11
# numespecificacaosubcota               5
# numlote                          737039
# nummes                               12
# numparcela                            2
# numressarcimento                      2
# numsubcota                           22
# sgpartido                            22
# sguf                                 22
# txnomeparlamentar                    22
# txtcnpjcpf                        93039
# txtdescricao                      93039
# txtdescricaoespecificacao         93039
# txtfornecedor                     93039
# txtnumero                         93039
# txtpassageiro                     93039
# txttrecho                         93039
# vlrdocumento                     240665
# vlrglosa                          22527
# vlrliquido                       236233
# vlrrestituicao                      648

# %% [markdown]
# Descrição dos campos:
#
# - codLegislatura -> Código da Legislatura
# - datEmissao -> Data de Emissão
# - ideCadastro -> Identificador Único do Parlamentar
# - indTipoDocumento -> Indicativo de Tipo de Documento Fiscal
# - nuCarteiraParlamentar -> Número da Carteira Parlamentar
# - nuDeputadoId -> Identificador do Solicitante
# - nuLegislatura -> Número da Legislatura
# - numAno -> Ano
# - numEspecificacaoSubCota -> Número da Especificação da Subcota
# - numLote -> Número do Lote
# - numMes -> Mês
# - numParcela -> Número da Parcela
# - numRessarcimento -> Número do Ressarcimento
# - numSubCota -> Número da Subcota
# - sgPartido -> Sigla do Partido
# - sgUF -> Sigla da UF
# - txNomeParlamentar -> Nome Parlamentar
# - txtCNPJCPF -> CNPJ/CPF
# - txtDescricao -> Descrição da Subcota
# - txtDescricaoEspecificacao -> Descrição da Especificação da Subcota
# - txtFornecedor -> Fornecedor
# - txtNumero -> Número do Documento
# - txtPassageiro -> Passageiro
# - txtTrecho -> Trecho
# - vlrDocumento -> Valor do Documento
# - vlrGlosa -> Valor da Glosa
# - vlrLiquido -> Valor Líquido
# - vlrRestituicao -> Valor da Restituição
